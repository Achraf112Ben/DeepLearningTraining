# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
        data_index = 0
        batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
        print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
        print('    batch:', [reverse_dictionary[bi] for bi in batch])
        print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                                                 stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                             train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.822782
# Nearest to may: sensing, handicapped, sampson, alpha, winsor, perfective, vicarage, stays,
# Nearest to five: organometallic, iala, robeson, kayak, unjust, hydrodynamics, guildhall, surprises,
# Nearest to be: modelling, chardin, broadcasted, sheriff, scarcely, blenheim, reproductions, bauhaus,
# Nearest to four: faceted, nursed, hypergeometric, mond, linkage, goodman, westermann, xxxvii,
# Nearest to of: catalans, ingres, jacobsen, barbera, ecologists, gir, reordering, landslide,
# Nearest to he: allusion, poisoned, sample, normalised, jomo, catalysed, lorraine, spokane,
# Nearest to two: stabilization, famed, illyricum, numerical, raeder, comforted, digits, leaping,
# Nearest to more: manzikert, tms, reviled, fireplace, modulating, curfew, benzodiazepine, anac,
# Nearest to at: trim, aguilera, tley, numismatic, salome, yankee, fer, eric,
# Nearest to there: programmed, turnbull, categorization, toshiba, vineyards, tactical, athletes, ozone,
# Nearest to his: munro, tons, terraforming, kiribati, vented, fathered, monsieur, khaldun,
# Nearest to to: recanted, acrimonious, perils, writ, omen, hst, revenge, averse,
# Nearest to when: whereas, lined, settled, fanning, resembled, sound, lighthouses, tou,
# Nearest to such: savers, aeneid, straddling, immutable, lahr, chanson, meddle, attackers,
# Nearest to not: subliminal, straddle, dispelling, bello, prisms, ernst, moneypenny, suffering,
# Nearest to that: taraza, whittaker, booty, insects, fermilab, phylogenetic, cynicism, annexed,
# Average loss at step 2000: 4.355449
# Average loss at step 4000: 3.861680
# Average loss at step 6000: 3.786645
# Average loss at step 8000: 3.687151
# Average loss at step 10000: 3.615716
# Nearest to may: would, can, consonance, sensing, could, winsor, sampson, fasts,
# Nearest to five: six, four, eight, nine, seven, three, zero, two,
# Nearest to be: have, was, is, were, southerly, been, decorative, do,
# Nearest to four: six, eight, five, three, seven, nine, zero, two,
# Nearest to of: in, for, barbera, vaults, dinah, and, impregnated, reordering,
# Nearest to he: it, she, they, who, there, tolstoy, commentaries, allusion,
# Nearest to two: five, three, four, seven, six, one, eight, nine,
# Nearest to more: curfew, bester, agni, wassily, krypton, braddock, most, barber,
# Nearest to at: in, on, from, melted, somoza, trim, hutton, of,
# Nearest to there: it, they, he, fowl, she, typeface, categorization, now,
# Nearest to his: their, s, the, its, her, dostoevsky, this, debates,
# Nearest to to: perils, not, should, hst, elly, unfairly, hotspot, basica,
# Nearest to when: fanning, gasses, whereas, sickle, resembled, lined, slight, ritz,
# Nearest to such: many, savers, these, immutable, battalions, bitterly, samadhi, some,
# Nearest to not: they, it, you, to, also, decalogue, he, renounced,
# Nearest to that: which, what, tile, favre, steed, it, she, booty,
# Average loss at step 12000: 3.605813
# Average loss at step 14000: 3.566857
# Average loss at step 16000: 3.411312
# Average loss at step 18000: 3.461286
# Average loss at step 20000: 3.541757
# Nearest to may: can, would, could, might, will, must, winsor, should,
# Nearest to five: six, eight, three, four, seven, zero, two, nine,
# Nearest to be: have, been, were, was, is, overwhelm, by, billed,
# Nearest to four: seven, three, six, eight, five, nine, two, zero,
# Nearest to of: lithuanian, barbera, original, dinah, vaults, gels, dealerships, viet,
# Nearest to he: it, she, they, who, there, this, fanfare, allusion,
# Nearest to two: five, four, three, six, eight, seven, zero, one,
# Nearest to more: most, less, krypton, agni, curfew, succumbed, anac, jarrett,
# Nearest to at: in, on, from, under, during, melted, indefensible, with,
# Nearest to there: it, they, he, she, which, generally, fowl, who,
# Nearest to his: their, her, its, the, dostoevsky, this, mersenne, yielded,
# Nearest to to: not, could, should, perils, elly, will, can, would,
# Nearest to when: during, fanning, if, where, whereas, gasses, sickle, slight,
# Nearest to such: many, these, known, trivia, infinity, battalions, cavities, weaned,
# Nearest to not: they, it, to, also, christof, you, renounced, we,
# Nearest to that: which, but, what, pregnancies, also, who, when, if,
# Average loss at step 22000: 3.502261
# Average loss at step 24000: 3.489563
# Average loss at step 26000: 3.487073
# Average loss at step 28000: 3.479906
# Average loss at step 30000: 3.506341
# Nearest to may: would, can, could, will, might, must, should, cannot,
# Nearest to five: seven, four, eight, three, six, nine, zero, two,
# Nearest to be: have, been, were, was, is, overwhelm, freiherr, are,
# Nearest to four: five, three, eight, seven, six, nine, two, zero,
# Nearest to of: in, gels, viet, from, hgp, for, original, greatest,
# Nearest to he: she, it, who, they, there, subspace, octavia, deadliest,
# Nearest to two: four, three, one, five, seven, eight, six, nine,
# Nearest to more: less, most, very, agni, replenish, krypton, barber, curfew,
# Nearest to at: in, near, under, during, on, loglan, melted, witold,
# Nearest to there: they, it, he, she, we, now, who, typeface,
# Nearest to his: her, their, its, the, dostoevsky, s, your, unconquered,
# Nearest to to: would, will, should, can, could, not, must, might,
# Nearest to when: if, where, during, with, after, before, was, although,
# Nearest to such: well, known, these, cavities, weaned, many, trivia, infinity,
# Nearest to not: generally, they, it, you, to, christof, harlow, we,
# Nearest to that: which, what, illiteracy, this, registers, if, receive, tile,
# Average loss at step 32000: 3.502195
# Average loss at step 34000: 3.498100
# Average loss at step 36000: 3.454811
# Average loss at step 38000: 3.304041
# Average loss at step 40000: 3.428478
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to five: seven, six, four, three, eight, nine, zero, two,
# Nearest to be: been, have, are, were, overwhelm, was, being, is,
# Nearest to four: six, three, seven, five, eight, nine, two, one,
# Nearest to of: in, original, from, vaults, ruins, barbera, abduction, dinah,
# Nearest to he: she, it, they, who, there, subspace, then, i,
# Nearest to two: three, five, six, four, seven, eight, one, nine,
# Nearest to more: less, most, very, curfew, braddock, auden, barber, resultant,
# Nearest to at: on, near, during, under, loglan, melted, witold, woz,
# Nearest to there: they, it, he, she, now, we, often, generally,
# Nearest to his: their, her, its, s, your, the, my, hybridization,
# Nearest to to: must, will, elly, can, could, perils, would, not,
# Nearest to when: if, where, before, during, while, although, after, as,
# Nearest to such: known, these, well, weaned, many, fu, cavities, battalions,
# Nearest to not: they, it, generally, still, you, now, harlow, christof,
# Nearest to that: which, what, this, morte, however, also, who, hoosiers,
# Average loss at step 42000: 3.434761
# Average loss at step 44000: 3.451200
# Average loss at step 46000: 3.447528
# Average loss at step 48000: 3.355926
# Average loss at step 50000: 3.378395
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to be: been, have, were, was, become, is, overwhelm, are,
# Nearest to four: eight, six, seven, five, three, nine, zero, two,
# Nearest to of: in, leclerc, viet, and, from, chechens, dealerships, including,
# Nearest to he: she, it, they, who, there, fanfare, subspace, then,
# Nearest to two: one, three, six, four, eight, seven, five, zero,
# Nearest to more: less, most, very, curfew, barber, smaller, modal, resultant,
# Nearest to at: during, near, loglan, in, witold, swells, under, bikram,
# Nearest to there: they, it, he, she, now, who, we, these,
# Nearest to his: their, her, its, your, my, ras, dostoevsky, him,
# Nearest to to: would, elly, should, may, could, enters, broadbent, must,
# Nearest to when: if, while, before, after, where, during, but, although,
# Nearest to such: known, well, these, many, weaned, glycoproteins, fu, cavities,
# Nearest to not: now, generally, you, harlow, they, considered, federer, never,
# Nearest to that: which, however, what, but, often, who, illiteracy, lillee,
# Average loss at step 52000: 3.439819
# Average loss at step 54000: 3.430291
# Average loss at step 56000: 3.438786
# Average loss at step 58000: 3.395181
# Average loss at step 60000: 3.392559
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Nearest to five: four, three, six, eight, seven, nine, zero, two,
# Nearest to be: been, have, overwhelm, become, are, was, seem, apply,
# Nearest to four: five, eight, six, seven, three, nine, zero, two,
# Nearest to of: in, for, including, chechens, leclerc, barbera, include, catalans,
# Nearest to he: she, it, they, who, there, fanfare, never, this,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to more: less, very, rather, most, other, barber, greater, smaller,
# Nearest to at: during, near, under, in, loglan, incorporating, witold, stratford,
# Nearest to there: they, it, she, now, he, we, still, this,
# Nearest to his: her, their, its, my, your, the, dostoevsky, badajoz,
# Nearest to to: elly, perils, should, would, retracted, loxodonta, materialists, endomorphism,
# Nearest to when: if, before, while, although, after, where, though, during,
# Nearest to such: these, well, known, many, glycoproteins, weaned, trivia, astrophysicists,
# Nearest to not: now, harlow, you, still, generally, usually, they, christof,
# Nearest to that: which, what, however, this, it, generally, sulphur, but,
# Average loss at step 62000: 3.241330
# Average loss at step 64000: 3.254006
# Average loss at step 66000: 3.401196
# Average loss at step 68000: 3.391563
# Average loss at step 70000: 3.355894
# Nearest to may: can, would, could, will, might, should, must, cannot,
# Nearest to five: six, four, eight, nine, seven, three, zero, two,
# Nearest to be: been, have, is, being, become, are, were, was,
# Nearest to four: six, seven, five, three, eight, two, zero, nine,
# Nearest to of: including, barbera, include, catalans, shredded, hgp, gels, for,
# Nearest to he: she, it, they, there, who, never, fanfare, deadliest,
# Nearest to two: three, four, seven, six, one, five, zero, eight,
# Nearest to more: less, most, very, highly, rather, fewer, barber, unwanted,
# Nearest to at: during, near, pituitary, under, in, on, card, loglan,
# Nearest to there: they, it, we, she, still, he, now, often,
# Nearest to his: her, their, its, my, your, the, badajoz, dostoevsky,
# Nearest to to: can, would, must, could, will, codepages, should, perils,
# Nearest to when: if, while, before, though, after, however, because, during,
# Nearest to such: these, known, well, many, glycoproteins, weaned, astrophysicists, some,
# Nearest to not: now, still, never, generally, harlow, unionist, also, lutz,
# Nearest to that: which, what, however, but, this, sulphur, madelyne, clearly,
# Average loss at step 72000: 3.378061
# Average loss at step 74000: 3.348713
# Average loss at step 76000: 3.314522
# Average loss at step 78000: 3.355677
# Average loss at step 80000: 3.380368
# Nearest to may: can, could, would, might, will, should, must, cannot,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to be: been, have, being, schiaparelli, is, are, become, were,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to of: including, in, original, albany, viet, gels, endanger, spinner,
# Nearest to he: she, it, they, there, who, never, fanfare, we,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to more: less, very, most, highly, faster, rather, unwanted, too,
# Nearest to at: in, pituitary, near, loglan, during, etiquette, on, before,
# Nearest to there: it, they, she, he, still, we, now, sometimes,
# Nearest to his: her, their, my, its, your, our, dostoevsky, bijelo,
# Nearest to to: elly, would, will, kingfisher, hoarding, exhaustion, diena, must,
# Nearest to when: before, if, during, after, while, though, then, because,
# Nearest to such: well, these, known, certain, glycoproteins, including, many, counterpoint,
# Nearest to not: still, actually, nor, generally, never, they, you, lutz,
# Nearest to that: which, however, what, lillee, defends, illiteracy, this, booty,
# Average loss at step 82000: 3.406147
# Average loss at step 84000: 3.412617
# Average loss at step 86000: 3.393598
# Average loss at step 88000: 3.350752
# Average loss at step 90000: 3.366864
# Nearest to may: can, might, could, would, should, must, will, cannot,
# Nearest to five: four, seven, eight, three, six, nine, two, zero,
# Nearest to be: been, have, become, being, was, is, schiaparelli, finely,
# Nearest to four: five, seven, eight, six, three, two, nine, one,
# Nearest to of: including, viet, for, christus, in, dealerships, catalans, limburgish,
# Nearest to he: she, it, they, there, who, but, later, we,
# Nearest to two: three, four, five, eight, six, seven, one, nine,
# Nearest to more: less, very, most, highly, rather, fewer, increasingly, too,
# Nearest to at: near, under, on, in, loglan, exacted, during, brl,
# Nearest to there: they, it, she, we, still, he, now, generally,
# Nearest to his: her, their, my, its, your, our, the, ras,
# Nearest to to: elly, would, broadbent, loxodonta, must, should, lakeside, towards,
# Nearest to when: if, before, while, after, during, where, though, because,
# Nearest to such: well, known, these, counterpoint, certain, acting, follows, regarded,
# Nearest to not: still, nor, never, now, actually, unionist, harlow, also,
# Nearest to that: which, however, what, illiteracy, but, clearly, defends, generally,
# Average loss at step 92000: 3.398090
# Average loss at step 94000: 3.248816
# Average loss at step 96000: 3.359153
# Average loss at step 98000: 3.238478
# Average loss at step 100000: 3.359247
# Nearest to may: can, could, should, might, must, would, will, cannot,
# Nearest to five: seven, four, six, eight, three, nine, two, zero,
# Nearest to be: been, have, is, are, being, become, refer, overwhelm,
# Nearest to four: seven, five, six, eight, three, nine, two, zero,
# Nearest to of: in, including, original, and, viet, shredded, attenuated, gels,
# Nearest to he: she, it, they, there, who, we, never, this,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to more: less, very, most, highly, rather, larger, greater, increasingly,
# Nearest to at: on, near, during, brl, exacted, doorways, pituitary, saville,
# Nearest to there: they, now, it, he, she, we, still, generally,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to to: will, towards, would, could, elly, should, and, kao,
# Nearest to when: if, while, before, after, though, where, although, because,
# Nearest to such: known, well, these, many, including, follows, defined, counterpoint,
# Nearest to not: never, nor, still, now, lutz, actually, also, restatement,
# Nearest to that: which, however, what, who, lillee, but, defends, riaa,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
